# %%
import tweepy

# %%
auth = tweepy.OAuthHandler("mPJDVRPVbYIOmTW0IXj4HLCS0", "q7zNQq6eCO1eQdx0KcyLcxeCpqebBrgiiaXJkoFpxZ7auveZxf")
auth.set_access_token("743093247573032966-M5uhMelccqVCXUW8axgVmZN0XMNuwfr", "Gy2tVFHAksb23fVirPJVdV03p3p92OV2iMbIKndBXD2NX")

# %%
api = tweepy.API(auth)

# %%
public_tweets = api.home_timeline()
for tweet in public_tweets:
    print tweet.text
# Out:
# .@MomsDemand founder @shannonrwatts: I'm the mom of a gay teen, there's no reason to arm hate https://t.co/bJ1qRLgFA0
# In a heated exchange with the Florida AG, Anderson Cooper did not back down https://t.co/ED2kHRRtEy https://t.co/WQAmXjLa49
# Reshad Jones ends @MiamiDolphins holdout after one day: https://t.co/vNox29Wvfw (via @RapSheet) https://t.co/zna8kcvFan
# Good Morning America! 🇺🇸 🇺🇸 https://t.co/smkWl7PThr
# Ad: To get “Full-presence” VR, @AMD believes software is the key to future advances. #AMDVR https://t.co/o3LvbKPmPS https://t.co/hJF3rdeuyt
# Legendary Craig Sager joins ABC’s #NBAFinals Game 6 broadcast team Thursday as sideline reporter! https://t.co/LUIT2fCAXG
# "We must choose to not live in terror" https://t.co/cUK5YH9GsT
# .@Knucklepuck23 &amp; #RedSox take on Orioles at 7:10: https://t.co/ZMt53EGDdp
#
# 📺 @NESN, ESPN 2, @MLBTV
# 📻 @WEEI https://t.co/sI9y2Sxzwx
# ...

# %%
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener

text_file = open("Twitter.txt", "w")

class listener(StreamListener):

    def on_status(self, status):
        print(status.text)
        text_file.write((status.text).encode('utf-8'))
        text_file.write('\n')
        #if status.author.verified:
        #    print status.text
        #if status.retweeted:
        #    print status.text
        #print status
    
    def on_error(self, status):
        print status

# %%
auth = OAuthHandler("mPJDVRPVbYIOmTW0IXj4HLCS0", "q7zNQq6eCO1eQdx0KcyLcxeCpqebBrgiiaXJkoFpxZ7auveZxf")
auth.set_access_token("743093247573032966-M5uhMelccqVCXUW8axgVmZN0XMNuwfr", "Gy2tVFHAksb23fVirPJVdV03p3p92OV2iMbIKndBXD2NX")

# %%
twitterStream = Stream(auth, listener())
twitterStream.filter(track=["$AAPL","$FB","$MSFT","$AMZN","$GOOG","#AAPL","#MSFT","#AMZN","#GOOG"])
# Out:
# This Grocer Is Screaming ‘Buy Me’:  https://t.co/sOdsc65gzi $GOOG $AAPL
# Former NBC Exec. Ben Silverman: Apple Needs to Get in the Digital Content Game $AAPL https://t.co/mQSoFqfehc
# businessinsider: Apple is changing the way you unlock your iPhone in iOS 10 $AAPL https://t.co/KbIpmpRwFu https://t.co/iPg3vF2j2G
# RT @BI_contributors: Apple is changing the way you unlock your iPhone in iOS 10 $AAPL https://t.co/0Zwd8Jfwvc https://t.co/OCjbszA7BY
# Excited much !!  https://t.co/Fd7EzAV1oO
# RT $QQQ HFT Algos triggered SELL in SIGMA-X, CROSSFINDER, ATS, LX @ 14:17, P/T 106.00 $MSFT $BIDU $IBM $PCLN $AMZN $AAPL $NFLX $FB $TSLA
# Deal: #Amazon Fire Tablet $39.99 - 6/15/16. Read more: https://t.co/hD1tUnmIqZ $AMZN
# VIDEO: SAP's North America President on #Microsoft-LinkedIn Deal. Read more: https://t.co/p8sKsCk8c6 $MSFT
# Most of $GOOGL + $FB revenue &amp; userbase growth is abroad. How are they growing these markets? Our deep dive:
# https://t.co/prSvzYhT3p #LCCAP
# ...

# %%
with open('twitter.txt') as f:
    lines = f.readlines()

# %%
text_file = open("twitter1.txt", "w")
for tweet in lines:
        #Convert to lower case
        tweet = tweet.lower()
        #Convert www.* or https?://* to URL
        tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','',tweet)
        #Convert @username to AT_USER
        tweet = re.sub('@[^\s]+','',tweet)
        #Remove rt from retweets
        if tweet.startswith("rt "):
            tweet = tweet[4:]
        #Remove additional white spaces
        tweet = re.sub('[\s]+', ' ', tweet)
        #Replace #word with word
        tweet = re.sub(r'#([^\s]+)', r'\1', tweet)
        #trim
        tweet = tweet.strip('\'"')
        print tweet
        text_file.write(tweet)
        text_file.write("\n")
# Out:
# this grocer is screaming ‘buy me’: $goog $aapl
# former nbc exec. ben silverman: apple needs to get in the digital content game $aapl
# businessinsider: apple is changing the way you unlock your iphone in ios 10 $aapl
# apple is changing the way you unlock your iphone in ios 10 $aapl
# excited much !!
# qqq hft algos triggered sell in sigma-x, crossfinder, ats, lx @ 14:17, p/t 106.00 $msft $bidu $ibm $pcln $amzn $aapl $nflx $fb $tsla
# deal: amazon fire tablet $39.99 - 6/15/16. read more: $amzn
# video: sap's north america president on microsoft-linkedin deal. read more: $msft
# most of $googl + $fb revenue &amp; userbase growth is abroad. how are they growing these markets? our deep dive:
#  lccap
# apple iphone ios10 technology
# $goog alphabet inc's (googl) next android os could possibly be named nutella: rumors:
# alphabet inc's (googl...
# apple is changing the way you unlock your iphone in ios 10 $aapl
# ...

# %%
import re
text_file = open("Apple.txt", "w")
for tweet in lines:
    if ("$aapl" in tweet.lower()) or ("#aapl" in tweet.lower()):
        #Convert to lower case
        tweet = tweet.lower()
        #Convert www.* or https?://* to URL
        tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','',tweet)
        #Convert @username to AT_USER
        tweet = re.sub('@[^\s]+','',tweet)
        #Remove rt from retweets
        if tweet.startswith("rt "):
            tweet = tweet[4:]
        #Remove additional white spaces
        tweet = re.sub('[\s]+', ' ', tweet)
        #Replace #word with word
        tweet = re.sub(r'#([^\s]+)', r'\1', tweet)
        #trim
        tweet = tweet.strip('\'"')
        text_file.write(tweet)
        text_file.write("\n")

# %%
text_file.close()

# %%
text_file = open("FB.txt", "w")
for tweet in lines:
    if ("$fb" in tweet.lower()) or ("#fb" in tweet.lower()):
        #Convert to lower case
        tweet = tweet.lower()
        #Convert www.* or https?://* to URL
        tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','',tweet)
        #Convert @username to AT_USER
        tweet = re.sub('@[^\s]+','',tweet)
        #Remove rt from retweets
        if tweet.startswith("rt "):
            tweet = tweet[4:]
        #Remove additional white spaces
        tweet = re.sub('[\s]+', ' ', tweet)
        #Replace #word with word
        tweet = re.sub(r'#([^\s]+)', r'\1', tweet)
        #trim
        tweet = tweet.strip('\'"')
        text_file.write(tweet)
        text_file.write("\n")

# %%
text_file = open("Microsoft.txt", "w")
for tweet in lines:
    if ("$msft" in tweet.lower()) or ("#msft" in tweet.lower()):
        #Convert to lower case
        tweet = tweet.lower()
        #Convert www.* or https?://* to URL
        tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','',tweet)
        #Convert @username to AT_USER
        tweet = re.sub('@[^\s]+','',tweet)
        #Remove rt from retweets
        if tweet.startswith("rt "):
            tweet = tweet[4:]
        #Remove additional white spaces
        tweet = re.sub('[\s]+', ' ', tweet)
        #Replace #word with word
        tweet = re.sub(r'#([^\s]+)', r'\1', tweet)
        #trim
        tweet = tweet.strip('\'"')
        text_file.write(tweet)
        text_file.write("\n")

# %%
text_file = open("Amazon.txt", "w")
for tweet in lines:
    if ("$amzn" in tweet.lower()) or ("#amzn" in tweet.lower()):
        #Convert to lower case
        tweet = tweet.lower()
        #Convert www.* or https?://* to URL
        tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','',tweet)
        #Convert @username to AT_USER
        tweet = re.sub('@[^\s]+','',tweet)
        #Remove rt from retweets
        if tweet.startswith("rt "):
            tweet = tweet[4:]
        #Remove additional white spaces
        tweet = re.sub('[\s]+', ' ', tweet)
        #Replace #word with word
        tweet = re.sub(r'#([^\s]+)', r'\1', tweet)
        #trim
        tweet = tweet.strip('\'"')
        text_file.write(tweet)
        text_file.write("\n")

# %%
text_file = open("Google.txt", "w")
for tweet in lines:
    if ("$goog" in tweet.lower()) or ("#goog" in tweet.lower()):
        #Convert to lower case
        tweet = tweet.lower()
        #Convert www.* or https?://* to URL
        tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','',tweet)
        #Convert @username to AT_USER
        tweet = re.sub('@[^\s]+','',tweet)
        #Remove rt from retweets
        if tweet.startswith("rt "):
            tweet = tweet[4:]
        #Remove additional white spaces
        tweet = re.sub('[\s]+', ' ', tweet)
        #Replace #word with word
        tweet = re.sub(r'#([^\s]+)', r'\1', tweet)
        #trim
        tweet = tweet.strip('\'"')
        text_file.write(tweet)
        text_file.write("\n")

# %%
text_file.close()

# %%
with open('neg1.txt') as f:
    lines = f.read().splitlines()
neg_tweets = []    
for item in lines:
    item.strip(" ")
    neg_tweets.append(item)
print neg_tweets
# Out:
# ['alibaba faces backlash over promises on counterfeits', 'is a horrible company horrible for small businesses and to its own employees', 'when you buy from you support the elimination of retail jobs in the us boycottamazon', 'pathetic again', "apple's price target lowered to at jpmorgan", 'giving up on', 'licensing business could suffer', 'the market is shrugging this off too', 'pay as you use license-included vm not supported anymore on azure badsurprise', 'cloudy, with a chance of stock falls', 'u.s. grocery sales disappoint, may be negative', 'downgraded just ahead', 'employees never work', 'hits 3-week low on weak stock draw', 'stock falls after downgrade ', 'losing streak', '6 days of stock market turbulence', 'Down Today', 'The  has been weakening for days now', 'Why this move in the yen is so darn scary', 'drop after merger news', 'Mostly Lower as Looms', "had weak first quarter, where  income fell  by is struggling as its stock fell again, nearing a record low as germany's yi
# ...

# %%
negative_tweets = []
for tweet in neg_tweets:
    negative_tweets.append((tweet,'negative'))
print negative_tweets
# Out:
# [('alibaba faces backlash over promises on counterfeits', 'negative'), ('is a horrible company horrible for small businesses and to its own employees', 'negative'), ('when you buy from you support the elimination of retail jobs in the us boycottamazon', 'negative'), ('pathetic again', 'negative'), ("apple's price target lowered to at jpmorgan", 'negative'), ('giving up on', 'negative'), ('licensing business could suffer', 'negative'), ('the market is shrugging this off too', 'negative'), ('pay as you use license-included vm not supported anymore on azure badsurprise', 'negative'), ('cloudy, with a chance of stock falls', 'negative'), ('u.s. grocery sales disappoint, may be negative', 'negative'), ('downgraded just ahead', 'negative'), ('employees never work', 'negative'), ('hits 3-week low on weak stock draw', 'negative'), ('stock falls after downgrade ', 'negative'), ('losing streak', 'negative'), ('6 days of stock market turbulence', 'negative'), ('Down Today', 'negative'), ('The  
# ...

# %%
with open('pos.txt') as f:
    lines = f.read().splitlines()
pos_tweets = []    
for item in lines:
    item.strip(" ")
    pos_tweets.append(item)
print pos_tweets
# Out:
# ['largest enterprises r embracing aws. just read client list', "amazon's iot strategy iot", 'has only widened the gap between it and other ecommerce players onlineshopping tech retailers', 'just bought some call options i think we rally tomorrow and friday', 'epages launches pay with amazon for ecommerce retailers in uk germany', 'web giant is top retail brand on social media brandwatch reports', 'apple maps will remember where you parked your\xa0car', 'the rise of apple in healthcare it', 'apple opens world-first training centre', 'traders bet big that apple is set to rise', 'apple\x92s new patent just stunned everyone', 'iphone 8 super cycle will drive apple shares up', 'apple gears up for huge watch 2 launch', 'apple software hints at future macbook features touch id and oled touch bars cnet', "i wouldn't short oracle into earnings.. tech stocks", 'drives global innovation by supporting womenintech let girls learn', 'today in corporation is incorporated in redwood shores, californ
# ...

# %%
pos_tweets = pos_tweets[:-1]
print pos_tweets
# Out:
# ['largest enterprises r embracing aws. just read client list', "amazon's iot strategy iot", 'has only widened the gap between it and other ecommerce players onlineshopping tech retailers', 'just bought some call options i think we rally tomorrow and friday', 'epages launches pay with amazon for ecommerce retailers in uk germany', 'web giant is top retail brand on social media brandwatch reports', 'apple maps will remember where you parked your\xa0car', 'the rise of apple in healthcare it', 'apple opens world-first training centre', 'traders bet big that apple is set to rise', 'apple\x92s new patent just stunned everyone', 'iphone 8 super cycle will drive apple shares up', 'apple gears up for huge watch 2 launch', 'apple software hints at future macbook features touch id and oled touch bars cnet', "i wouldn't short oracle into earnings.. tech stocks", 'drives global innovation by supporting womenintech let girls learn', 'today in corporation is incorporated in redwood shores, californ
# ...

# %%
positive_tweets = []
for tweet in pos_tweets:
    positive_tweets.append((tweet,'positive'))
print positive_tweets
# Out:
# [('largest enterprises r embracing aws. just read client list', 'positive'), ("amazon's iot strategy iot", 'positive'), ('has only widened the gap between it and other ecommerce players onlineshopping tech retailers', 'positive'), ('just bought some call options i think we rally tomorrow and friday', 'positive'), ('epages launches pay with amazon for ecommerce retailers in uk germany', 'positive'), ('web giant is top retail brand on social media brandwatch reports', 'positive'), ('apple maps will remember where you parked your\xa0car', 'positive'), ('the rise of apple in healthcare it', 'positive'), ('apple opens world-first training centre', 'positive'), ('traders bet big that apple is set to rise', 'positive'), ('apple\x92s new patent just stunned everyone', 'positive'), ('iphone 8 super cycle will drive apple shares up', 'positive'), ('apple gears up for huge watch 2 launch', 'positive'), ('apple software hints at future macbook features touch id and oled touch bars cnet', 'positi
# ...

# %%
tweets = []
for (words, sentiment) in positive_tweets + negative_tweets:
    words_filtered = [e for e in words.split() if len(e) >= 3]
    tweets.append((words_filtered, sentiment))
print tweets
# Out:
# [(['largest', 'enterprises', 'embracing', 'aws.', 'just', 'read', 'client', 'list'], 'positive'), (["amazon's", 'iot', 'strategy', 'iot'], 'positive'), (['has', 'only', 'widened', 'the', 'gap', 'between', 'and', 'other', 'ecommerce', 'players', 'onlineshopping', 'tech', 'retailers'], 'positive'), (['just', 'bought', 'some', 'call', 'options', 'think', 'rally', 'tomorrow', 'and', 'friday'], 'positive'), (['epages', 'launches', 'pay', 'with', 'amazon', 'for', 'ecommerce', 'retailers', 'germany'], 'positive'), (['web', 'giant', 'top', 'retail', 'brand', 'social', 'media', 'brandwatch', 'reports'], 'positive'), (['apple', 'maps', 'will', 'remember', 'where', 'you', 'parked', 'your\xa0car'], 'positive'), (['the', 'rise', 'apple', 'healthcare'], 'positive'), (['apple', 'opens', 'world-first', 'training', 'centre'], 'positive'), (['traders', 'bet', 'big', 'that', 'apple', 'set', 'rise'], 'positive'), (['apple\x92s', 'new', 'patent', 'just', 'stunned', 'everyone'], 'positive'), (['iphone', '
# ...

# %%
import nltk

# %%
def get_words_in_tweets(tweets):
    all_words = []
    for (words, sentiment) in tweets:
        all_words.extend(words)
    return all_words

# %%
def get_word_features(wordlist):
    wordlist = nltk.FreqDist(wordlist)
    word_features = wordlist.keys()
    return word_features

# %%
import itertools
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures
 
def bigram_word_feats(words, score_fn=BigramAssocMeasures.chi_sq, n=200):
    bigram_finder = BigramCollocationFinder.from_words(words)
    bigrams = bigram_finder.nbest(score_fn, n)
    return dict([(ngram, True) for ngram in itertools.chain(words, bigrams)])

# %%
bigram_features = bigram_word_feats(get_words_in_tweets(tweets))

# %%
print bigram_features
# Out:
# {('lie:', 'shift'): True, ('above', 'expectations'): True, 'caused': True, 'global': True, ('grocery', 'sales'): True, ('promises', 'counterfeits'): True, 'milk': True, 'Today': True, ('merger', 'news'): True, ('employees', 'never'): True, ('target', 'lowered'): True, ('sdl', 'inc'): True, 'weakening': True, 'brandwatch': True, 'pledges': True, ('again,', 'nearing'): True, 'rise': True, ('corporation', 'incorporated'): True, ('call', 'options'): True, ('azure', 'badsurprise'): True, ('books?', '(tm)'): True, 'cnet': True, ('milk', 'ever'): True, ('may', 'negative'): True, 'Global': True, 'list': True, ('social', 'media'): True, ('caused', 'drop'): True, 'launches': True, 'small': True, 'work': True, ('announcements', 'buying'): True, ('enterprises', 'embracing'): True, 'nearing': True, ('Retail', 'sales'): True, 'widened': True, ('could', 'suffer'): True, 'shrugging': True, ("wouldn't", 'short'): True, ('oracle', 'into'): True, ('into', 'earnings..'): True, ('huge', 'watch'): True, '
# ...

# %%
word_features =  get_word_features(get_words_in_tweets(tweets))

# %%
def extract_features(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in document_words)
    return features

# %%
extract_features(['largest', 'enterprises', 'embracing', 'aws.', 'just', 'read', 'client', 'list'])
# Out:
# {'contains((overlandpark,)': False,
#  'contains((tm))': False,
#  'contains(-25.09)': False,
#  'contains(3-week)': False,
#  'contains(CFO)': False,
#  'contains(Down)': False,
#  'contains(For)': False,
#  'contains(From)': False,
#  'contains(Global)': False,
#  "contains(Here's)": False,
#  'contains(Looms)': False,
#  'contains(Lower)': False,
#  'contains(Mostly)': False,
#  'contains(Retail)': False,
#  'contains(Revenue)': False,
#  'contains(The)': False,
#  'contains(Today)': False,
#  'contains(Trend)': False,
#  'contains(Upward)': False,
#  'contains(Why)': False,
#  'contains(above)': False,
#  'contains(ads)': False,
#  'contains(after)': False,
#  'contains(again)': False,
#  'contains(again,)': False,
#  'contains(ahead)': False,
#  'contains(alibaba)': False,
#  "contains(amazon's)": False,
#  'contains(amazon)': False,
#  'contains(and)': False,
#  'contains(announcements)': False,
#  'contains(anymore)': False,
#  "contains(apple's)": False,
# ...

# %%
training_set = nltk.classify.apply_features(extract_features, tweets)

# %%
classifier = nltk.NaiveBayesClassifier.train(training_set)

# %%
tweet = 'Oracle earnings soar'
print classifier.classify(extract_features(tweet.split()))
# Out:
# positive

# %%
pos_count = 0
neg_count = 0
with open('oracle3.txt') as f:
    lines = f.read().splitlines()
for tweet in lines:
    result = classifier.classify(extract_features(tweet.split()))
    if (result == "positive"):
        pos_count += 1
    else:
        neg_count += 1
print pos_count, neg_count
# Out:
# 2292 652

# %%
pos_count = 0
neg_count = 0
with open('before_oracle.txt') as f:
    lines = f.read().splitlines()
for tweet in lines:
    result = classifier.classify(extract_features(tweet.split()))
    if (result == "positive"):
        pos_count += 1
    else:
        neg_count += 1
print pos_count, neg_count
# Out:
# 515 243
